# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline
sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = (14, 8)

# %%
Match_df=pd.read_csv("Matches IPL 2020.csv")

# %%
Match_df.head()
# Out:
#         id  season         city        date team1 team2 toss_winner  \
# 0  1216492    2020    Abu Dhabi  09/19/2020    MI   CSK         CSK
# 1  1216493    2020  Dubai (DSC)  09/20/2020    DC  KXIP        KXIP
# 2  1216534    2020  Dubai (DSC)  09/21/2020   SRH   RCB         SRH
# 3  1216496    2020      Sharjah  09/22/2020    RR   CSK         CSK
# 4  1216508    2020    Abu Dhabi  09/23/2020   KKR    MI         KKR
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    CSK            0               5
# 1         field     tie           0     DC            0               0
# 2         field  normal           0    RCB           10               0
# 3         field  normal           0     RR           16               0
# 4         field  normal           0     MI           49               0
#
#   player_of_match                                venue  \
# 0       AT Rayudu      Sheikh Zayed Stadium, Abu Dhabi
# ...

# %%
Match_df.isnull()
# Out:
#        id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0   False   False  False  False  False  False        False          False
# 1   False   False  False  False  False  False        False          False
# 2   False   False  False  False  False  False        False          False
# 3   False   False  False  False  False  False        False          False
# 4   False   False  False  False  False  False        False          False
# 5   False   False  False  False  False  False        False          False
# 6   False   False  False  False  False  False        False          False
# 7   False   False  False  False  False  False        False          False
# 8   False   False  False  False  False  False        False          False
# 9   False   False  False  False  False  False        False          False
# 10  False   False  False  False  False  False        False          False
# 11  False   False  False  False  False  False        False          False
# ...

# %%
Match_df.drop(['season'], axis = 1)
# Out:
#          id         city        date team1 team2 toss_winner toss_decision  \
# 0   1216492    Abu Dhabi  09/19/2020    MI   CSK         CSK         field
# 1   1216493  Dubai (DSC)  09/20/2020    DC  KXIP        KXIP         field
# 2   1216534  Dubai (DSC)  09/21/2020   SRH   RCB         SRH         field
# 3   1216496      Sharjah  09/22/2020    RR   CSK         CSK         field
# 4   1216508    Abu Dhabi  09/23/2020   KKR    MI         KKR         field
# 5   1216510  Dubai (DSC)  09/24/2020  KXIP   RCB         RCB         field
# 6   1216539  Dubai (DSC)  09/25/2020   CSK    DC         CSK         field
# 7   1216545    Abu Dhabi  09/26/2020   KKR   SRH         SRH           bat
# 8   1216527      Sharjah  09/27/2020    RR  KXIP          RR         field
# 9   1216547  Dubai (DSC)  09/28/2020   RCB    MI          MI         field
# 10  1216532    Abu Dhabi  09/29/2020    DC   SRH          DC         field
# ...

# %%
import sweetviz as sv
report=sv.analyze(Match_df)
report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sns.set_style("dark")
ls=Match_df['venue'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(10,4))

temp =sns.barplot(ls.index, ls.values, alpha=0.8)
plt.title('MOST PLAYED VENUE')
plt.ylabel('COUNT', fontsize=14)
plt.xlabel('NAME OF THE STADIUMS', fontsize=15)
temp.set_xticklabels(rotation=90,labels=ls.index,fontsize=8)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sns.set_style("dark")
ls=Match_df['winner'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(10,4))

temp =sns.barplot(ls.index, ls.values, alpha=0.8)
plt.title('Points Table')
plt.ylabel('Points', fontsize=14)
plt.xlabel('Teams', fontsize=15)
temp.set_xticklabels(rotation=90,labels=ls.index,fontsize=10)
plt.show()

# %%
temp=pd.concat([Match_df['umpire1'],Match_df['umpire2'],Match_df['umpire3']]).value_counts().sort_values(ascending=False)
plt.figure(figsize=(20,5))
Most_umpired =sns.barplot(x=temp.index, y=temp.values, alpha=0.9)

plt.title('Favorite umpire')
plt.ylabel('Count', fontsize=12)
plt.xlabel('Name of the Umpire', fontsize=15)
Most_umpired.set_xticklabels(rotation=90,labels=temp.index,fontsize=15)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sns.set_style("dark")
ls=Match_df['toss_winner'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(10,4))

temp =sns.barplot(ls.index, ls.values, alpha=0.8)
plt.title('Toss Winners')
plt.ylabel('', fontsize=14)
plt.xlabel('Teams', fontsize=15)
temp.set_xticklabels(rotation=90,labels=ls.index,fontsize=10)
plt.show()

# %%
Dubai_stadium=Match_df.loc[(Match_df['venue']=='Dubai International Cricket Stadium') ]
Dubai_stadium_win_by_runs=Dubai_stadium[Dubai_stadium['win_by_runs']>0]
slices=[len(Dubai_stadium_win_by_runs),len(Dubai_stadium)-len(Dubai_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=20,shadow=1,explode=(0,0.2),autopct='%2.3f%%',colors=['red','green'])
plt.title('Dubai International Cricket Stadium')
plt.show()

# %%
Sheikh_stadium=Match_df.loc[(Match_df['venue']=='Sheikh Zayed Stadium, Abu Dhabi') ]
Sheikh_stadium_win_by_runs=Sheikh_stadium[Sheikh_stadium['win_by_runs']>0]
slices=[len(Sheikh_stadium_win_by_runs),len(Sheikh_stadium)-len(Sheikh_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=20,shadow=1,explode=(0,0.2),autopct='%2.3f%%',colors=['red','green'])
plt.title('Sheikh Zayed Stadium, Abu Dhabi')
plt.show()

# %%
Sharjah_stadium=Match_df.loc[(Match_df['venue']=='Sharjah Cricket Stadium')]

Sharjah_stadium_win_by_runs=Sharjah_stadium[Sharjah_stadium['win_by_runs']>0]
slices=[len(Sharjah_stadium_win_by_runs),len(Sharjah_stadium)-len(Sharjah_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=20,shadow=1,explode=(0,0.2),autopct='%2.3f%%',colors=['red','green'])
plt.title('Sharjah Cricket Stadium')
plt.show()
